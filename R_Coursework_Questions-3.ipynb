# %% [markdown]
# # R Coursework part 1

# %% [markdown]
# Answer all of the questions below in the cells provided.
#
# Make sure you:
#
# - comment your code
# - run your cells to check your answers
# - save your notebook with your answers before submitting it

# %% [markdown]
# ### Question 1

# %% [markdown]
# Create a data frame with 5 rows and 2 columns. The first column should be a vector of names of your choice, the second should be a series of numeric values.

# %%
column1 <- c("CAT", "DOG", "FOX", "FROG", "ELEPHANT")
column2 <- c(1, 2, 3, 4, 5)
df = data.frame(Column1= column1, Column2= column2)
print(df)
# Out:
#    Column1 Column2
# 1      CAT       1
# 2      DOG       2
# 3      FOX       3
# 4     FROG       4
# 5 ELEPHANT       5

# %% [markdown]
# ### Question 2

# %% [markdown]
# The code in the cell below provides examples of each of the main data structures in R. Run the code in the cell below.

# %%
my_vector <- seq(from = 1, to = 1000, by = 1)
my_matrix <- matrix(1:100, nrow = 10, ncol = 10)
my_dataframe <- data.frame(name = rep(c("a", "b"), each = 10), value = 21:40)
my_list <- list(my_vector, my_matrix, my_dataframe)

# %% [markdown]
# Show how to access:
#
# - The 4th value of the vector
# - Column 4 and row 7 of the matrix
# - The 10th value of name in the data.frame
# - The 5th element of the 1st element of the list

# %%
print(my_vector[4]) 
my_matrix[4,]
my_matrix[,7]
my_matrix[4,7]
print(my_dataframe$name[10])
print(my_list[1][5])
# Out:
# [1] 4
#  [1]  4 14 24 34 44 54 64 74 84 94
#  [1] 61 62 63 64 65 66 67 68 69 70
# [1] 64
# [1] "a"
# [[1]]
# NULL

# %% [markdown]
# ### Question 3

# %% [markdown]
# Show three different ways to print the numbers 200 to 300 in R. One should be a `for` loop, one should be an `sapply` function and the third can be a method of your choosing.

# %%
for (i in 200:300)
print (i)
 
identity <- function(x)
 return(x)
 sapply(200:300,identity,simplify = FALSE)

cat(200:300, sep = "\n")
# Out:
# [1] 200
# [1] 201
# [1] 202
# [1] 203
# [1] 204
# [1] 205
# [1] 206
# [1] 207
# [1] 208
# [1] 209
# [1] 210
# [1] 211
# [1] 212
# [1] 213
# [1] 214
# [1] 215
# [1] 216
# [1] 217
# [1] 218
# [1] 219
# [1] 220
# [1] 221
# [1] 222
# [1] 223
# [1] 224
# [1] 225
# [1] 226
# [1] 227
# [1] 228
# [1] 229
# [1] 230
# [1] 231
# [1] 232
# [1] 233
# [1] 234
# [1] 235
# [1] 236
# [1] 237
# [1] 238
# [1] 239
# [1] 240
# [1] 241
# [1] 242
# [1] 243
# [1] 244
# [1] 245
# [1] 246
# [1] 247
# [1] 248
# [1] 249
# [1] 250
# [1] 251
# [1] 252
# [1] 253
# [1] 254
# [1] 255
# [1] 256
# [1] 257
# [1] 258
# [1] 259
# [1] 260
# [1] 261
# [1] 262
# [1] 263
# [1] 264
# [1] 265
# [1] 266
# [1] 267
# [1] 268
# [1] 269
# [1] 270
# [1] 271
# [1] 272
# [1] 273
# [1] 274
# [1] 275
# [1] 276
# [1] 277
# [1] 278
# [1] 279
# [1] 280
# [1] 281
# [1] 282
# [1] 283
# [1] 284
# [1] 285
# [1] 286
# [1] 287
# [1] 288
# [1] 289
# [1] 290
# [1] 291
# [1] 292
# [1] 293
# [1] 294
# [1] 295
# [1] 296
# [1] 297
# [1] 298
# [1] 299
# [1] 300
# [[1]]
# [1] 200
#
# [[2]]
# [1] 201
#
# [[3]]
# [1] 202
#
# [[4]]
# [1] 203
#
# [[5]]
# [1] 204
#
# [[6]]
# [1] 205
#
# [[7]]
# [1] 206
#
# [[8]]
# [1] 207
#
# [[9]]
# [1] 208
#
# [[10]]
# [1] 209
#
# [[11]]
# [1] 210
#
# [[12]]
# [1] 211
#
# [[13]]
# [1] 212
#
# [[14]]
# [1] 213
#
# [[15]]
# [1] 214
#
# [[16]]
# [1] 215
#
# [[17]]
# [1] 216
#
# [[18]]
# [1] 217
#
# [[19]]
# [1] 218
#
# [[20]]
# [1] 219
#
# [[21]]
# [1] 220
#
# [[22]]
# [1] 221
#
# [[23]]
# [1] 222
#
# [[24]]
# [1] 223
#
# [[25]]
# [1] 224
#
# [[26]]
# [1] 225
#
# [[27]]
# [1] 226
#
# [[28]]
# [1] 227
#
# [[29]]
# [1] 228
#
# [[30]]
# [1] 229
#
# [[31]]
# [1] 230
#
# [[32]]
# [1] 231
#
# [[33]]
# [1] 232
#
# [[34]]
# [1] 233
#
# [[35]]
# [1] 234
#
# [[36]]
# [1] 235
#
# [[37]]
# [1] 236
#
# [[38]]
# [1] 237
#
# [[39]]
# [1] 238
#
# [[40]]
# [1] 239
#
# [[41]]
# [1] 240
#
# [[42]]
# [1] 241
#
# [[43]]
# [1] 242
#
# [[44]]
# [1] 243
#
# [[45]]
# [1] 244
#
# [[46]]
# [1] 245
#
# [[47]]
# [1] 246
#
# [[48]]
# [1] 247
#
# [[49]]
# [1] 248
#
# [[50]]
# [1] 249
#
# [[51]]
# [1] 250
#
# [[52]]
# [1] 251
#
# [[53]]
# [1] 252
#
# [[54]]
# [1] 253
#
# [[55]]
# [1] 254
#
# [[56]]
# [1] 255
#
# [[57]]
# [1] 256
#
# [[58]]
# [1] 257
#
# [[59]]
# [1] 258
#
# [[60]]
# [1] 259
#
# [[61]]
# [1] 260
#
# [[62]]
# [1] 261
#
# [[63]]
# [1] 262
#
# [[64]]
# [1] 263
#
# [[65]]
# [1] 264
#
# [[66]]
# [1] 265
#
# [[67]]
# [1] 266
#
# [[68]]
# [1] 267
#
# [[69]]
# [1] 268
#
# [[70]]
# [1] 269
#
# [[71]]
# [1] 270
#
# [[72]]
# [1] 271
#
# [[73]]
# [1] 272
#
# [[74]]
# [1] 273
#
# [[75]]
# [1] 274
#
# [[76]]
# [1] 275
#
# [[77]]
# [1] 276
#
# [[78]]
# [1] 277
#
# [[79]]
# [1] 278
#
# [[80]]
# [1] 279
#
# [[81]]
# [1] 280
#
# [[82]]
# [1] 281
#
# [[83]]
# [1] 282
#
# [[84]]
# [1] 283
#
# [[85]]
# [1] 284
#
# [[86]]
# [1] 285
#
# [[87]]
# [1] 286
#
# [[88]]
# [1] 287
#
# [[89]]
# [1] 288
#
# [[90]]
# [1] 289
#
# [[91]]
# [1] 290
#
# [[92]]
# [1] 291
#
# [[93]]
# [1] 292
#
# [[94]]
# [1] 293
#
# [[95]]
# [1] 294
#
# [[96]]
# [1] 295
#
# [[97]]
# [1] 296
#
# [[98]]
# [1] 297
#
# [[99]]
# [1] 298
#
# [[100]]
# [1] 299
#
# [[101]]
# [1] 300
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300

# %% [markdown]
# ### Question 4

# %% [markdown]
# The following code creates a vector of animal names: (run this code)

# %%
animals <- c("tiger", "lion", "badger", "fox", "rabbit", "fish", "dog", "octopus")

# %% [markdown]
# Show how you would replace the fish and octopus in this dataset with two other animals without creating a new vector.

# %%
animals[1] <- 'a'
animals[2] <- 'b'
print(animals)
# Out:
# [1] "a"       "b"       "badger"  "fox"     "rabbit"  "fish"    "dog"
# [8] "octopus"

# %% [markdown]
# ### Question 5

# %% [markdown]
# Using the `cars` dataset, make a `baseR` (i.e. do not use `ggplot2`) scatterplot of speed vs distance Ensure the x and y labels do not include cars$ and give your plot an appropriate title.
#
# HINT: you will have to begin by loading the cars dataset

# %%
data(cars)
plot(cars$speed, cars$dist,main='speed&dist',
     xlab='speed', ylab='dist')
# Out:
# Plot with title “speed&dist”

# %% [markdown]
# ### Question 6

# %% [markdown]
# Using the `starwars` dataset, identify the individuals with:
#
# - the tallest height
# - the lowest mass
#
# HINT: the starwars dataset is part of the dplyr package

# %%
library(dplyr)
data("starwars", package = "dplyr")
tallest_individual <- starwars %>%
  filter(height == max(height, na.rm = TRUE))

lowest_mass_individual <- starwars %>%
  filter(mass == min(mass, na.rm = TRUE))

cat("Individual with the tallest height:\n")
print(tallest_individual)

cat("\nIndividual with the lowest mass:\n")
print(lowest_mass_individual)
# Out:
# Individual with the tallest height:
# # A tibble: 1 × 14
#   name      height  mass hair_color skin_color eye_color birth_year sex   gender
#   <chr>      <int> <dbl> <chr>      <chr>      <chr>          <dbl> <chr> <chr>
# 1 Yarael P…    264    NA none       white      yellow            NA male  mascu…
# # ℹ 5 more variables: homeworld <chr>, species <chr>, films <list>,
# #   vehicles <list>, starships <list>
#
# Individual with the lowest mass:
# # A tibble: 1 × 14
#   name      height  mass hair_color skin_color eye_color birth_year sex   gender
#   <chr>      <int> <dbl> <chr>      <chr>      <chr>          <dbl> <chr> <chr>
# 1 Ratts Ty…     79    15 none       grey, blue unknown           NA male  mascu…
# # ℹ 5 more variables: homeworld <chr>, species <chr>, films <list>,
# #   vehicles <list>, starships <list>

# %% [markdown]
# ### Question 7

# %% [markdown]
# The `dplyr` dataset `storms` is part of the US National Oceanic and Atmospheric Administration database of Atlantic hurricanes. It contains multiple repeated measurements from hurricanes. For a given storm, there are measurements from every 6 hours across the life time of the storm.
#
# Use a tidyverse approach with `dplyr` to answer the following:
#
# - how many different storms are contained in the database?
# - which year had the most storms?
# - which storm, in which year had the highest pressure?
#
# HINT:
# unique() will help ensure you remove duplicated data from a vector e.g.
# x <- c(1, 1, 2, 2, 3, 3, 4, 4)
# unique(x)

# %%
data(storms)
unique(storms)
storm_counts <- table(storms$name)
print(storm_counts)

most_storms_year <- storms %>%
  distinct(name, year) %>% 
  count(year, name = "num_storms") %>%  
  arrange(desc(num_storms)) %>%         
  slice(1)                         

cat("Year with the most storms:\n")
print(most_storms_year)

highest_pressure_storm <- storms %>%
  filter(pressure == max(pressure, na.rm = TRUE)) %>%  
  select(name, year, pressure)                      

cat("Storm with the highest pressure:\n")
print(highest_pressure_storm)
# Out:
#       name   year month day hour lat  long  status              category wind
# 1     Amy    1975 6     27   0   27.5 -79.0 tropical depression NA       25
# 2     Amy    1975 6     27   6   28.5 -79.0 tropical depression NA       25
# 3     Amy    1975 6     27  12   29.5 -79.0 tropical depression NA       25
# 4     Amy    1975 6     27  18   30.5 -79.0 tropical depression NA       25
# 5     Amy    1975 6     28   0   31.5 -78.8 tropical depression NA       25
# 6     Amy    1975 6     28   6   32.4 -78.7 tropical depression NA       25
# 7     Amy    1975 6     28  12   33.3 -78.0 tropical depression NA       25
# 8     Amy    1975 6     28  18   34.0 -77.0 tropical depression NA       30
# 9     Amy    1975 6     29   0   34.4 -75.8 tropical storm      NA       35
# 10    Amy    1975 6     29   6   34.0 -74.8 tropical storm      NA       40
# 11    Amy    1975 6     29  12   33.8 -73.8 tropical storm      NA       45
# 12    Amy    1975 6     29  18   33.8 -72.8 tropical storm      NA       50
# 13    Amy    1975 6     30   0   34.3 -71.6 tropical storm      NA       50
# 14    Amy    1975 6     30   6   35.6 -70.8 tropical storm      NA       55
# 15    Amy    1975 6     30  12   35.9 -70.5 tropical storm      NA       60
# 16    Amy    1975 6     30  18   36.2 -70.2 tropical storm      NA       60
# 17    Amy    1975 7      1   0   36.2 -69.8 tropical storm      NA       60
# 18    Amy    1975 7      1   6   36.2 -69.4 tropical storm      NA       60
# 19    Amy    1975 7      1  12   36.2 -68.3 tropical storm      NA       60
# 20    Amy    1975 7      1  18   36.7 -67.2 tropical storm      NA       60
# 21    Amy    1975 7      2   0   37.4 -66.7 tropical storm      NA       60
# 22    Amy    1975 7      2   6   37.3 -65.9 tropical storm      NA       60
# 23    Amy    1975 7      2  12   37.3 -65.1 tropical storm      NA       60
# 24    Amy    1975 7      2  18   37.3 -64.1 tropical storm      NA       60
# 25    Amy    1975 7      3   0   37.7 -62.8 tropical storm      NA       55
# 26    Amy    1975 7      3   6   38.2 -61.2 tropical storm      NA       55
# 27    Amy    1975 7      3  12   39.3 -59.6 tropical storm      NA       55
# 28    Amy    1975 7      3  18   40.5 -58.0 tropical storm      NA       50
# 29    Amy    1975 7      4   0   42.5 -54.8 tropical storm      NA       50
# 30    Amy    1975 7      4   6   44.5 -51.6 tropical storm      NA       50
# ⋮     ⋮      ⋮    ⋮     ⋮   ⋮    ⋮    ⋮     ⋮                   ⋮        ⋮
# 19506 Martin 2022 11     4   0   52.7 -38.0 extratropical       NA       70
# 19507 Martin 2022 11     4   6   54.7 -37.7 extratropical       NA       65
# 19508 Martin 2022 11     4  12   55.8 -37.2 extratropical       NA       60
# 19509 Martin 2022 11     4  18   56.5 -36.5 extratropical       NA       55
# 19510 Nicole 2022 11     6  12   20.6 -66.8 other low           NA       30
# 19511 Nicole 2022 11     6  18   22.4 -66.8 other low           NA       35
# 19512 Nicole 2022 11     7   0   23.9 -67.5 other low           NA       35
# 19513 Nicole 2022 11     7   6   25.2 -68.2 subtropical storm   NA       40
# 19514 Nicole 2022 11     7  12   25.9 -69.3 subtropical storm   NA       40
# 19515 Nicole 2022 11     7  18   26.4 -70.3 subtropical storm   NA       40
# 19516 Nicole 2022 11     8   0   26.8 -70.7 subtropical storm   NA       40
# 19517 Nicole 2022 11     8   6   27.5 -71.2 subtropical storm   NA       40
# 19518 Nicole 2022 11     8  12   27.7 -72.1 subtropical storm   NA       45
# 19519 Nicole 2022 11     8  18   27.6 -73.3 tropical storm      NA       50
# 19520 Nicole 2022 11     9   0   27.2 -74.3 tropical storm      NA       60
# 19521 Nicole 2022 11     9   6   26.8 -75.3 tropical storm      NA       60
# 19522 Nicole 2022 11     9  12   26.5 -76.2 tropical storm      NA       55
# 19523 Nicole 2022 11     9  17   26.5 -77.1 tropical storm      NA       60
# 19524 Nicole 2022 11     9  18   26.5 -77.3 tropical storm      NA       60
# 19525 Nicole 2022 11     9  23   26.6 -78.2 hurricane            1       65
# 19526 Nicole 2022 11    10   0   26.7 -78.4 hurricane            1       65
# 19527 Nicole 2022 11    10   6   27.3 -79.8 hurricane            1       65
# 19528 Nicole 2022 11    10   7   27.6 -80.3 hurricane            1       65
# 19529 Nicole 2022 11    10  12   28.0 -81.6 tropical storm      NA       55
# 19530 Nicole 2022 11    10  18   29.0 -82.8 tropical storm      NA       40
# 19531 Nicole 2022 11    10  19   29.2 -83.0 tropical storm      NA       40
# 19532 Nicole 2022 11    11   0   30.1 -84.0 tropical storm      NA       35
# 19533 Nicole 2022 11    11   6   31.2 -84.6 tropical depression NA       30
# 19534 Nicole 2022 11    11  12   33.2 -84.6 tropical depression NA       25
# 19535 Nicole 2022 11    11  18   35.4 -83.8 other low           NA       25
#       pressure tropicalstorm_force_diameter hurricane_force_diameter
# 1     1013     NA                           NA
# 2     1013     NA                           NA
# 3     1013     NA                           NA
# 4     1013     NA                           NA
# 5     1012     NA                           NA
# 6     1012     NA                           NA
# 7     1011     NA                           NA
# 8     1006     NA                           NA
# 9     1004     NA                           NA
# 10    1002     NA                           NA
# 11    1000     NA                           NA
# 12     998     NA                           NA
# 13     998     NA                           NA
# 14     998     NA                           NA
# 15     987     NA                           NA
# 16     987     NA                           NA
# 17     984     NA                           NA
# 18     984     NA                           NA
# 19     984     NA                           NA
# 20     984     NA                           NA
# 21     984     NA                           NA
# 22     984     NA                           NA
# 23     981     NA                           NA
# 24     986     NA                           NA
# 25     986     NA                           NA
# 26     986     NA                           NA
# 27     986     NA                           NA
# 28     986     NA                           NA
# 29     986     NA                           NA
# 30     986     NA                           NA
# ⋮     ⋮        ⋮                            ⋮
# 19506  947      990                         100
# 19507  936     1050                         100
# 19508  932     1170                           0
# 19509  939     1170                           0
# 19510 1005        0                           0
# 19511 1005      120                           0
# 19512 1005      240                           0
# 19513 1004      240                           0
# 19514 1002      310                           0
# 19515 1001      350                           0
# 19516  998      450                           0
# 19517  996      570                           0
# 19518  993      570                           0
# 19519  991      570                           0
# 19520  984      570                           0
# 19521  986      520                           0
# 19522  985      520                           0
# 19523  985      520                           0
# 19524  985      480                           0
# 19525  980      480                          20
# 19526  980      480                          20
# 19527  980      570                          20
# 19528  980      570                          20
# 19529  984      480                           0
# 19530  989      300                           0
# 19531  989      300                           0
# 19532  992      300                           0
# 19533  996        0                           0
# 19534  999        0                           0
# 19535 1000        0                           0
#  AL011993  AL012000  AL021992  AL021994  AL021999  AL022000  AL022001  AL022003
#        11         4         5         6         4        12         5         4
#  AL022006  AL031987  AL031992  AL041991  AL042000  AL051994  AL061988  AL061995
#        13        32         8         7        13         9        13         9
#  AL061997  AL062003  AL071999  AL072002  AL072003  AL081992  AL081994  AL091994
#         8         8         8         5         7        25        10         7
#  AL092000  AL092001  AL092003  AL101991  AL101993  AL101994  AL102004  AL111999
#         6         4         4         5         5         7        13        10
#  AL121991  AL121999  AL141995  AL142002  AL142003  Al202011   Alberto      Alex
#        22        12        17        11        10        14       233       142
#    Alicia     Allen   Allison     Alpha    Amelia       Amy       Ana    Andrea
#        25        44       121        11         6        31       189        14
#    Andrew     Anita    Arlene    Arthur      Babe     Barry     Belle    Bertha
#        68        20       199       172        10       165        18       261
#     Beryl      Bess      Beta      Bill   Blanche       Bob    Bonnie      Bret
#       181        13        52       109        20       105       328       138
#   Candice  Caroline     Cesar   Chantal   Charley     Chris     Cindy     Clara
#        11        33        61       171       163       198       164        27
# Claudette     Colin      Cora Cristobal  Danielle     Danny     David      Dean
#       237        46        19       115       276       197        55       148
#     Debby     Debra     Delta    Dennis     Diana     Dolly       Don    Dorian
#       170         7        73       244        58       107        21       121
#     Doris   Dorothy    Dottie      Earl   Edouard     Eight     Elena    Eleven
#        29        15        10       260       228        32        46        17
#      Ella    Eloise      Elsa     Emily      Emmy   Epsilon     Erika      Erin
#        27        46        43       236        31        84       124       184
#   Ernesto       Eta    Evelyn    Fabian       Fay      Faye     Felix   Fernand
#       152        58        10        97       124        19       206        16
#   Fifteen     Fiona      Five  Florence   Flossie     Floyd      Four      Fran
#        39       116        32       239        19       131         9       104
#   Frances  Franklin      Fred  Frederic    Frieda Gabrielle     Gamma    Gaston
#       215        71       124        68        10       196        54       145
#   Georges      Gert   Gilbert    Gladys    Gloria   Gonzalo    Gordon     Grace
#       103       171        49        46       144        62       196       135
#     Greta    Gustav    Hallie     Hanna    Harvey    Helene     Henri   Hermine
#        12       161        14       121       198       228       154       136
#     Holly      Hope  Hortense      Hugo  Humberto       Ian       Ida      Igor
#         7        16       119        64       158        61       122        61
#       Ike    Imelda    Ingrid      Iota     Irene      Iris      Irma     Isaac
#        62         9        48        26       176       109        72       170
#    Isabel    Isaias   Isidore      Ivan    Jeanne     Jerry      Joan   Joaquin
#        94        36       168       175       158       138        53        76
#      Jose Josephine     Joyce      Juan     Julia    Julian    Juliet     Karen
#       152       231        79        51       105        13        16       132
#      Karl      Kate     Katia   Katrina     Keith    Kendra      Kirk     Klaus
#       181       133        82        70        74        11        50        58
#      Kyle     Larry     Laura       Lee     Lenny    Leslie      Lili      Lisa
#       127        88        76       111        39       175       204       168
#   Lorenzo      Luis     Marco     Maria   Marilyn    Martin   Matthew   Melissa
#        99        61       100       161        79        21        79        82
#   Michael  Michelle     Mindy     Mitch    Nadine      Nana      Nate    Nestor
#       102        35        24        78       127        50        84        15
#  Nicholas    Nicole      Nine  Nineteen      Noel    Odette      Olga      Omar
#       101       136        19         9       113        66        82        59
#       One      Opal   Ophelia     Oscar      Otto     Pablo    Paloma     Patty
#        15        39       175        49       124        38        36        11
#     Paula  Paulette     Peter  Philippe    Rafael      Rene   Richard      Rina
#        21        88        31       100        56        32        29        52
#      Rita      Rose   Roxanne     Sally       Sam     Sandy      Sean Sebastien
#        36        22        56        28        59        45        28        53
#     Shary   Sixteen      Stan     Tammy     Tanya     Teddy       Ten     Theta
#         9         8        17         9        29        49        48        33
#     Three     Tomas      Tony    Twelve       Two     Vicky    Victor     Vince
#         5        54        20        10        30        24        22        15
#     Wanda   Wilfred     Wilma      Zeta
#        54        17        48        61
# Year with the most storms:
# # A tibble: 1 × 2
#    year num_storms
#   <dbl>      <int>
# 1  2020         30
# Storm with the highest pressure:
# # A tibble: 2 × 3
#   name   year pressure
#   <chr> <dbl>    <int>
# 1 Danny  2003     1024
# 2 Danny  2003     1024

# %% [markdown]
# ### Question 8

# %% [markdown]
# The `ggplot2` dataset `diamonds` contains the price and information from the sale of 54,000 different diamonds. You can use ?diamonds to find out more about the dataset if you want.
#
# Using `ggplot2`:
#
# - plot the relationship between the carat (i.e. the weight of the diamond) and the price.
# - plot a histogram of prices of all the diamonds
# - plot a boxplot of the difference in price between the different cuts

# %%
library(ggplot2)
data(diamonds)
ggplot(diamonds, aes(x = carat, y = price)) +
  geom_point(alpha = 0.9, color = "yellow") +
  labs(title = "Relationship between Carat and Price",
       x = "Carat (Weight of Diamond)",
       y = "Price (in USD)") 

ggplot(diamonds, aes(x = price)) +
  geom_histogram(bins = 50, fill = "blue", color = "black", alpha = 0.9) +
  labs(title = "Histogram of Diamond Prices",
       x = "Price (in USD)",
       y = "Frequency") 

ggplot(diamonds, aes(x = cut, y = price)) +
  geom_boxplot(fill = "lightblue", color = "green") +
  labs(title = "Boxplot of Diamond Prices by Cut",
       x = "Cut of Diamond",
       y = "Price (in USD)")
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Question 9

# %% [markdown]
# Identify the maximum and minimum price that the diamonds in the diamonds data set sold for. Add a new column to the diamonds data set that contains the string “Low price” if the value in the price column is less than 5000 dollars and “High price” if it is above 5000 dollars.

# %%
max_price <- max(diamonds$price)
min_price <- min(diamonds$price)

cat("Maximum price:", max_price, "\n")
cat("Minimum price:", min_price, "\n")

diamonds <- diamonds %>%
  mutate(price_category = ifelse(price < 5000, "Low price", "High price"))

head(diamonds)
# Out:
# Maximum price: 18823
# Minimum price: 326
#   carat cut       color clarity depth table price x    y    z    price_category
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43 Low price
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31 Low price
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31 Low price
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63 Low price
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75 Low price
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48 Low price

# %% [markdown]
# ### Question 10

# %% [markdown]
# Sticking with the `diamonds` dataset for this question. A carat is a special unit of weight for gemstones where a single carat is 200 mg or 0.2 g. Write a function to convert the `diamonds$carat` vector into grams or milligrams. How heavy is the heaviest diamond?

# %%
convert_carat <- function(carat, to_unit = "grams") {
  if (to_unit == "grams") {
    return(carat * 0.2) 
  } else if (to_unit == "milligrams") {
    return(carat * 200) 
  } else {
    stop("Invalid unit. Use 'grams' or 'milligrams'.")
  }
}

diamonds$weight_in_grams <- convert_carat(diamonds$carat, "grams")
diamonds$weight_in_milligrams <- convert_carat(diamonds$carat, "milligrams")

heaviest_diamond_weight_grams <- max(diamonds$weight_in_grams)
heaviest_diamond <- diamonds %>%
  filter(weight_in_grams == heaviest_diamond_weight_grams)

cat("The heaviest diamond weighs:", heaviest_diamond_weight_grams, "grams\n")
print("Details of the heaviest diamond:")
print(heaviest_diamond)
# Out:
# The heaviest diamond weighs: 1.002 grams
# [1] "Details of the heaviest diamond:"
# # A tibble: 1 × 13
#   carat cut   color clarity depth table price     x     y     z price_category
#   <dbl> <ord> <ord> <ord>   <dbl> <dbl> <int> <dbl> <dbl> <dbl> <chr>
# 1  5.01 Fair  J     I1       65.5    59 18018  10.7  10.5  6.98 High price
# # ℹ 2 more variables: weight_in_grams <dbl>, weight_in_milligrams <dbl>
